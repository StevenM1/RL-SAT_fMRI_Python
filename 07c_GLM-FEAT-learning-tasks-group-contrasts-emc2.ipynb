# %%
import os, sys                                  # system functions
import nipype.interfaces.io as nio           # Data i/o
from nipype.interfaces.io import DataSink
import nipype.interfaces.fsl as fsl          # fsl
import nipype.pipeline.engine as pe          # pypeline engine
import nipype.interfaces.utility as util     # utility
import nipype.algorithms.modelgen as model   # model generation
import errno
import glob
import pandas as pd

fsl.FSLCommand.set_default_output_type('NIFTI_GZ')

# %% [markdown]
# ### Copes at level 2:
# ##### Model 1:
# conditions =
# - 'cuestimrespfeedback',
# - 'response_leftminright',
# - 'cue_SPDminACC',
# - 'stimulus_value_difference',
# - 'feedback_PE'

# %%
# general set-up
project_folder = '/home/Public/trondheim'
work_dir = os.path.join(project_folder, 'processing', 'nipype_workflow_folders')
# The directory where we can find the level 2 output
slm_folder = os.path.join(project_folder, 'derivatives', 'glm_feat', 'subject_level_model')


spaces = ['T1w']   # shouldn't touch this but just in case we _do_ want to go back to MNI....
ses = 'rlsat'      # don't make this a list, that won't work
task = 'rlsat'     # don't make this a list, that won't work
model_ns = ['1-dm-RTdur']      # 
fwhms = ['1p5']

template_brain = '/home/Public/trondheim/sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii'
template_brain_mask = '/home/Public/trondheim/sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain_mask.nii'

subject_ids = sorted(glob.glob(os.path.join(project_folder, 'derivatives', 'glm_feat', 'subject_level_model', 'sub-*', 'ses-rlsat', 'func', 'fwhm-1p5', 'model-{}'.format(model_ns[0]))))
subject_ids = [x.split('/')[-5].split('-')[-1] for x in subject_ids]

## TMP
#subject_ids = subject_ids[:-1]

contrasts = ['0','1','2','3','4', '5']  # from second-level model

templates = {'level2_cope': os.path.join(slm_folder, 'sub-*', 'ses-rlsat', 'func', 'fwhm-{fwhm}', 'model-{model_n}', '*ses-rlsat_task-rlsat_space-MNI152NLin2009cAsym_model-{model_n}_contrast-{contrast_n}_desc-cope.nii.gz'),
             'level2_varcope': os.path.join(slm_folder, 'sub-*', 'ses-rlsat', 'func', 'fwhm-{fwhm}', 'model-{model_n}', '*ses-rlsat_task-rlsat_space-MNI152NLin2009cAsym_model-{model_n}_contrast-{contrast_n}_desc-varcope.nii.gz'),
             'level2_tdof': os.path.join(slm_folder, 'sub-*', 'ses-rlsat', 'func', 'fwhm-{fwhm}', 'model-{model_n}', '*ses-rlsat_task-rlsat_space-MNI152NLin2009cAsym_model-{model_n}_contrast-{contrast_n}_desc-tdof_t.nii.gz')}

# %%
# ## make brain mask for flameo
# import nilearn
# from nilearn import plotting
# import nibabel as nib

# hdr = nib.load('../sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain.nii')
# brain_data = hdr.get_fdata()
# brain_data[brain_data>0] = 1
# brain_mask = nib.Nifti1Image(brain_data, affine=hdr.affine, header=hdr.header)
# brain_mask.to_filename('../sourcedata/templates/mni_icbm152_t1_tal_nlin_asym_09c_brain_mask.nii')

# %%
##
workflow = pe.Workflow(name='feat_level3_rlsat') ## TMP
workflow.base_dir = os.path.join(project_folder, 'processing', 'nipype_workflow_folders')
workflow.config = {"execution": {"crashdump_dir":os.path.join(project_folder, 'processing', 'crashdumps')}}

# Identity
identity = pe.Node(util.IdentityInterface(fields=['contrast_n', 'model_n', 'fwhm']), name='identity')
identity.iterables = [('contrast_n', contrasts),
                      ('fwhm', fwhms),
                      ('model_n', model_ns)]

# Selector
selector = pe.Node(nio.SelectFiles(templates), name='selector')
workflow.connect(identity, 'contrast_n', selector, 'contrast_n')
workflow.connect(identity, 'fwhm', selector, 'fwhm')
workflow.connect(identity, 'model_n', selector, 'model_n')

## Merge copes, varcopes, masks
copemerge    = pe.Node(interface=fsl.Merge(dimension='t'),
                          name="copemerge")

varcopemerge = pe.Node(interface=fsl.Merge(dimension='t'),
                       name="varcopemerge")

workflow.connect(selector, 'level2_cope', copemerge, 'in_files')
workflow.connect(selector, 'level2_varcope', varcopemerge, 'in_files')

# %%
# pd.DataFrame(get_design_matrix('0', get_subject_ids())[1])

# %%
def get_subject_ids():
    import glob
    import os
    subject_ids = sorted(glob.glob(os.path.join('/home/Public/trondheim', 'derivatives', 'glm_feat', 'subject_level_model', 'sub-*', 'ses-rlsat')))
    subject_ids = [x.split('/')[-2].split('-')[-1] for x in subject_ids]
    
    return subject_ids

subject_id_getter = pe.Node(util.Function(output_names=['subject_ids'],
                                          function=get_subject_ids),
                            name='subject_id_getter')

def get_design_matrix(second_level_contrast, subject_ids):
    print(second_level_contrast)
    regressors = {'intercept': [1 for x in range(len(subject_ids))]}
    
    if second_level_contrast == '0':  # SPD-ACC
        import pandas as pd
        # find behavioral model parameters
        parameters = pd.read_csv('/home/Public/trondheim/derivatives/behavior/task-rlsat_model-RLARD-v0B_group_parameters.tsv', sep='\t')
        for colname in ['v0_cues-a', 'B_cues-a']:
            parameters[colname+'_z'] = (parameters[colname]-parameters[colname].mean())/parameters[colname].std()
        
        parameters['subject_label'] = parameters['subjects'].apply(lambda x: str(x).zfill(3))
        thresholds = [parameters.loc[parameters.subject_label==x, 'B_cues-a_z'].values[0].round(5) for x in subject_ids]
        urgencies = [parameters.loc[parameters.subject_label==x, 'v0_cues-a_z'].values[0].round(5) for x in subject_ids]
        regressors['threshold'] = thresholds
        regressors['urgency'] = urgencies
#         parameters = pd.read_csv('/home/Public/trondheim/scripts/RLDMC/diagnostics/model-arw-RL-mag-SAT-B2_data-rlsat/medianParametersBPICs.csv').rename(columns={'Unnamed: 0': 'sub'}).iloc[:-2]
#         parameters['B0.spd'] = parameters['B0']*(1+parameters['B0Mod.SPD'])
#         parameters['threshold_z'] = parameters['B0']-parameters['B0.spd']
#         parameters['threshold_z'] = (parameters['threshold_z'] - parameters['threshold_z'].mean()) / (parameters['threshold_z'].std())
#         # parameters['threshold_z'] = (parameters['B0Mod.SPD'] - parameters['B0Mod.SPD'].mean())/parameters['B0Mod.SPD'].std()
#         # parameters['threshold_z'] = (parameters['B0Mod.SPD'] - parameters['B0Mod.SPD'].mean())/parameters['B0Mod.SPD'].std()
#         parameters['subject_label'] = parameters['sub'].apply(lambda x: str(x).zfill(3))
#         thresholds = [parameters.loc[parameters.subject_label==x, 'threshold_z'].values[0].round(5) for x in subject_ids]
    
#         regressors['threshold'] = thresholds

        # contrasts (3rd-level), include model-based covariate
        third_level_contrasts = [('Group mean', 'T', ['intercept', 'threshold', 'urgency'], [1.0, 0, 0]),
                                 ('-Group mean', 'T', ['intercept', 'threshold', 'urgency'], [-1.0, 0, 0]),
                                 ('Threshold', 'T', ['intercept', 'threshold', 'urgency'], [0, 1, 0]),
                                 ('-Threshold', 'T', ['intercept', 'threshold', 'urgency'], [0, -1, 0]),
                                 ('Urgency', 'T', ['intercept', 'threshold', 'urgency'], [0, 0, 1]),
                                 ('-Urgency', 'T', ['intercept', 'threshold', 'urgency'], [0, 0, -1]),
                                 ]
    else:
        # contrasts (3rd-level)
        third_level_contrasts = [('Group mean', 'T', ['intercept'], [1.0]),
                                 ('-Group mean', 'T', ['intercept'], [-1.0])
                                 ]
    
    return third_level_contrasts, regressors



contrastgen_l3 = pe.Node(util.Function(input_names=['second_level_contrast', 'subject_ids'],
                                       output_names=['third_level_contrasts', 'regressors'],
                                       function=get_design_matrix),
                      name='contrastgen_l3')

level3model = pe.Node(interface=fsl.MultipleRegressDesign(),
                      name='l3model')


workflow.connect(subject_id_getter, 'subject_ids', contrastgen_l3, 'subject_ids')
workflow.connect(identity, 'contrast_n', contrastgen_l3, 'second_level_contrast')
workflow.connect(contrastgen_l3, 'third_level_contrasts', level3model, 'contrasts')
workflow.connect(contrastgen_l3, 'regressors', level3model, 'regressors')

# %%
flameo = pe.Node(
    interface=fsl.FLAMEO(),
    name="flameo")

flameo.iterables = ('run_mode', ['flame1', 'flame12'])
flameo.inputs.mask_file = template_brain_mask
flameo.inputs.infer_outliers = False # True   # run with automatic outlier detection ## Seems to crash for contrast 3 (value)

workflow.connect([
    (copemerge, flameo, [('merged_file', 'cope_file')]),
    (varcopemerge, flameo, [('merged_file', 'var_cope_file')]),
    (level3model, flameo, [('design_mat', 'design_file'),
                           ('design_con', 't_con_file'), 
                           ('design_grp', 'cov_split_file')]),
])

# %%
## cluster thresholding
# Smoothness estimation
smoothestimate = pe.MapNode(fsl.SmoothEstimate(), iterfield=['zstat_file'], name='smoothestimate')
smoothestimate.inputs.mask_file = template_brain_mask

workflow.connect(flameo, 'zstats', smoothestimate, 'zstat_file')

# get volume
get_volume = pe.Node(fsl.ImageStats(op_string = '-V'), name='get_volume')
get_volume.inputs.in_file = template_brain_mask


# Cluster threshold
grf_cluster = pe.MapNode(fsl.Cluster(), iterfield=['dlh', 'in_file'], name='grf_cluster')
grf_cluster.iterables = [("threshold", [2.3, 3.1])]
grf_cluster.inputs.out_localmax_txt_file = True
grf_cluster.inputs.pthreshold = 0.05
grf_cluster.inputs.out_index_file = True
grf_cluster.inputs.out_threshold_file = True


def volume_convert(input):
    return int(input[0])

workflow.connect(get_volume, ('out_stat', volume_convert), grf_cluster, 'volume')
workflow.connect(smoothestimate, 'dlh', grf_cluster, 'dlh')
workflow.connect(flameo, 'zstats', grf_cluster, 'in_file')

# %%
## Datasink
datasink = pe.Node(nio.DataSink(), name='sinker')
datasink.inputs.base_directory=os.path.join(project_folder, 'derivatives', "glm_feat", "group_level_model", "ses-rlsat")


# substitutions = [(f't1w/level2_{stat_type}s/_model_n_{model_n_}_smoothing_fwhm_{fwhm}_space_T1w_subject_id_{sub}/_flameo{contrast_n}/{stat_type}1.nii.gz',
#                   f'sub-{sub}/ses-{ses}/func/fwhm-{fwhm}/model-{model_n_}/sub-{sub}_ses-{ses}_task-{task}_space-T1w_model-{model_n_}_contrast-{contrast_n}_desc-{stat_type}.nii.gz')
#                   for sub in subject_ids
#                   for contrast_n in range(len(contrasts))
#                   for model_n_ in model_n
#                   for fwhm in smoothing_fwhm
#                   for stat_type in ['cope', 'zstat', 'varcope', 'tdof_t']
#                   ]


#grf_thresholded_zstats_file/_contrast_n_0_fwhm_1p5_model_n_0a-z/_run_mode_flame12

substitutions_regexp = [(r'third_level_model/grf_thresholded_zstats_file/_contrast_n_(\d+)_fwhm_(\S{3})_model_n_(\S+)/_run_mode_flame(\d+)/_threshold_(\S+)/_grf_cluster(\d)/(\S+)(\d)_threshold.nii.gz',
                         'model-\\3/model-\\3_fwhm-\\2_subjectlevelcontrast-\\1_grouplevelcontrast-\\8_flame-\\4_desc-\\7_voxelthreshold-\\5.nii.gz'),
                        (r'third_level_model/level3_.*/_contrast_n_(\d+)_fwhm_(\S{3})_model_n_(\S+)/_run_mode_flame(\d+)/(\S+)(\d).nii.gz',
                          'model-\\3/model-\\3_fwhm-\\2_subjectlevelcontrast-\\1_grouplevelcontrast-\\6_flame-\\4_desc-\\5.nii.gz'),
                        # (r'third_level_model/grf_localmax_.*/fwhm-(\S{3})/model-(\S+)/contrast-(\d+)/_run_mode_flame(\d+)/_threshold_(\S+)/_grf_cluster(\d)/zstat1_(\S+).txt',
                        #   'model-\\2/model-\\2_fwhm-\\1_subjectlevelcontrast-\\3_grouplevelcontrast-\\6_flame-\\4_desc-zstat_\\7-voxelthreshold-\\5.txt')
                       ]

# substitutions = [(f'_contrast_n_{contrast_n}_fwhm_{fwhm}_model_n_{model_n}',
#                   f'fwhm-{fwhm}/model-{model_n}/contrast-{contrast_n}') 
#                  for contrast_n in contrasts
#                  for model_n in model_ns
#                  for fwhm in fwhms]
datasink.inputs.regexp_substitutions = substitutions_regexp


# workflow.connect(copemerge, 'merged_file', datasink, 'copes_merged')
# workflow.connect(level3model, 'design_con', datasink, 'design_con')
# workflow.connect(level3model, 'design_mat', datasink, 'design_mat')

## todo: substitutions
workflow.connect(flameo, 'zstats', datasink, 'third_level_model.level3_zstats')
workflow.connect(flameo, 'copes', datasink, 'third_level_model.level3_copes')
workflow.connect(flameo, 'var_copes', datasink, 'third_level_model.level3_varcopes')
workflow.connect(flameo, 'tdof', datasink, 'third_level_model.level3_tdof_ts')

## cluster results
workflow.connect(grf_cluster, 'threshold_file', datasink, 'third_level_model.grf_thresholded_zstats_file')
workflow.connect(grf_cluster, 'localmax_txt_file', datasink, 'third_level_model.grf_localmax_txt_file')
workflow.connect(grf_cluster, 'index_file', datasink, 'third_level_model.grf_cluster_indices')

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs': 22})
# Out:
# 241120-15:09:14,122 nipype.workflow INFO:
# 	 Workflow feat_level3_rlsat settings: ['check', 'execution', 'logging', 'monitoring']
# 241120-15:09:14,332 nipype.workflow INFO:
# 	 Running in parallel.
# 241120-15:09:15,21 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 22/22.
# 241120-15:09:15,117 nipype.workflow INFO:
# 	 [Job 0] Cached (feat_level3_rlsat.subject_id_getter).
# 241120-15:09:15,119 nipype.workflow INFO:
# 	 [Job 1] Cached (feat_level3_rlsat.get_volume).
# 241120-15:09:15,194 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/selector".
# 241120-15:09:15,195 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/selector".
# 241120-15:09:15,195 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/selector".
# 241120-15:09:15,196 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/selector".
# 241120-15:09:15,196 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/selector".
# 241120-15:09:15,196 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/selector".
# 241120-15:09:15,262 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 241120-15:09:15,262 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 241120-15:09:15,262 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 241120-15:09:15,262 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 241120-15:09:15,262 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 241120-15:09:15,262 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 241120-15:09:15,278 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.013691s.
# 241120-15:09:15,278 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.013367s.
# 241120-15:09:15,278 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.013219s.
# 241120-15:09:15,278 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.013601s.
# 241120-15:09:15,278 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.013466s.
# 241120-15:09:15,278 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.013741s.
# 241120-15:09:17,24 nipype.workflow INFO:
# 	 [Job 2] Completed (feat_level3_rlsat.selector).
# 241120-15:09:17,25 nipype.workflow INFO:
# 	 [Job 3] Completed (feat_level3_rlsat.selector).
# 241120-15:09:17,26 nipype.workflow INFO:
# 	 [Job 4] Completed (feat_level3_rlsat.selector).
# 241120-15:09:17,27 nipype.workflow INFO:
# 	 [Job 5] Completed (feat_level3_rlsat.selector).
# 241120-15:09:17,27 nipype.workflow INFO:
# 	 [Job 6] Completed (feat_level3_rlsat.selector).
# 241120-15:09:17,28 nipype.workflow INFO:
# 	 [Job 7] Completed (feat_level3_rlsat.selector).
# 241120-15:09:17,29 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 18 jobs ready. Free memory (GB): 453.15/453.15, Free processors: 22/22.
# 241120-15:09:17,83 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.contrastgen_l3" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/contrastgen_l3".
# 241120-15:09:17,83 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.contrastgen_l3" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/contrastgen_l3".
# 241120-15:09:17,83 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.contrastgen_l3" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/contrastgen_l3".
# 241120-15:09:17,85 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.contrastgen_l3" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/contrastgen_l3".
# 241120-15:09:17,85 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.contrastgen_l3" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/contrastgen_l3".
# 241120-15:09:17,85 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.contrastgen_l3" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/contrastgen_l3".
# 241120-15:09:17,86 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.copemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/copemerge".
# 241120-15:09:17,86 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.varcopemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/varcopemerge".
# 241120-15:09:17,86 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.copemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/copemerge".
# 241120-15:09:17,88 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.varcopemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/varcopemerge".
# 241120-15:09:17,88 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.copemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/copemerge".
# 241120-15:09:17,88 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.varcopemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/varcopemerge".
# 241120-15:09:17,89 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.varcopemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/varcopemerge".
# 241120-15:09:17,89 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.copemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/copemerge".
# 241120-15:09:17,90 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.copemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/copemerge".
# 241120-15:09:17,91 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.varcopemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/varcopemerge".
# 241120-15:09:17,91 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.copemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/copemerge".
# 241120-15:09:17,90 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.varcopemerge" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/varcopemerge".
# 241120-15:09:17,95 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,95 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,96 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,97 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,97 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,97 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,97 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,98 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,98 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,99 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,99 nipype.workflow INFO:
# 	 [Node] Executing "copemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,99 nipype.workflow INFO:
# 	 [Node] Executing "varcopemerge" <nipype.interfaces.fsl.utils.Merge>
# 241120-15:09:17,104 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 241120-15:09:17,104 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 241120-15:09:17,104 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 1241120-15:09:17,104 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 241120-15:09:17,104 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 241120-15:09:17,104 nipype.workflow INFO:
# 	 [Node] Executing "contrastgen_l3" <nipype.interfaces.utility.wrappers.Function>
# 5234
# 0
#
#
#
# 241120-15:09:17,109 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.002658s.
# 241120-15:09:17,110 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.002918s.
# 241120-15:09:17,110 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.004093s.
# 241120-15:09:17,109 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.003303s.
#
# 241120-15:09:17,114 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.00784s.
# 241120-15:09:17,173 nipype.workflow INFO:
# 	 [Node] Finished "contrastgen_l3", elapsed time 0.066035s.
# 241120-15:09:19,24 nipype.workflow INFO:
# 	 [Job 8] Completed (feat_level3_rlsat.contrastgen_l3).
# 241120-15:09:19,26 nipype.workflow INFO:
# 	 [Job 9] Completed (feat_level3_rlsat.contrastgen_l3).
# 241120-15:09:19,27 nipype.workflow INFO:
# 	 [Job 10] Completed (feat_level3_rlsat.contrastgen_l3).
# 241120-15:09:19,28 nipype.workflow INFO:
# 	 [Job 11] Completed (feat_level3_rlsat.contrastgen_l3).
# 241120-15:09:19,28 nipype.workflow INFO:
# 	 [Job 12] Completed (feat_level3_rlsat.contrastgen_l3).
# 241120-15:09:19,29 nipype.workflow INFO:
# 	 [Job 13] Completed (feat_level3_rlsat.contrastgen_l3).
# 241120-15:09:19,30 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 6 jobs ready. Free memory (GB): 450.75/453.15, Free processors: 10/22.
#                      Currently running:
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
# 241120-15:09:19,72 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.l3model" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/l3model".
# 241120-15:09:19,73 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.l3model" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/l3model".
# 241120-15:09:19,78 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 241120-15:09:19,79 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 241120-15:09:19,79 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.l3model" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/l3model".
# 241120-15:09:19,79 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.l3model" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/l3model".
# 241120-15:09:19,80 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.l3model" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/l3model".
# 241120-15:09:19,81 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.001238s.
# 241120-15:09:19,82 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.00116s.
# 241120-15:09:19,81 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.l3model" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/l3model".
# 241120-15:09:19,83 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 241120-15:09:19,85 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 241120-15:09:19,86 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.000856s.
# 241120-15:09:19,87 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 241120-15:09:19,89 nipype.workflow INFO:
# 	 [Node] Executing "l3model" <nipype.interfaces.fsl.model.MultipleRegressDesign>
# 241120-15:09:19,90 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.000887s.
# 241120-15:09:19,90 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.000906s.
# 241120-15:09:19,93 nipype.workflow INFO:
# 	 [Node] Finished "l3model", elapsed time 0.000856s.
# 241120-15:09:21,26 nipype.workflow INFO:
# 	 [Job 26] Completed (feat_level3_rlsat.l3model).
# 241120-15:09:21,28 nipype.workflow INFO:
# 	 [Job 27] Completed (feat_level3_rlsat.l3model).
# 241120-15:09:21,29 nipype.workflow INFO:
# 	 [Job 28] Completed (feat_level3_rlsat.l3model).
# 241120-15:09:21,30 nipype.workflow INFO:
# 	 [Job 29] Completed (feat_level3_rlsat.l3model).
# 241120-15:09:21,30 nipype.workflow INFO:
# 	 [Job 30] Completed (feat_level3_rlsat.l3model).
# 241120-15:09:21,31 nipype.workflow INFO:
# 	 [Job 31] Completed (feat_level3_rlsat.l3model).
# 241120-15:09:21,32 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 450.75/453.15, Free processors: 10/22.
#                      Currently running:
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
# 241120-15:09:45,982 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 28.881782s.
# 241120-15:09:46,46 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 28.946295s.
# 241120-15:09:46,397 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 29.29748s.
# 241120-15:09:46,969 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 29.870763s.
# 241120-15:09:47,51 nipype.workflow INFO:
# 	 [Job 18] Completed (feat_level3_rlsat.copemerge).
# 241120-15:09:47,52 nipype.workflow INFO:
# 	 [Job 19] Completed (feat_level3_rlsat.varcopemerge).
# 241120-15:09:47,53 nipype.workflow INFO:
# 	 [Job 21] Completed (feat_level3_rlsat.varcopemerge).
# 241120-15:09:47,53 nipype.workflow INFO:
# 	 [Job 24] Completed (feat_level3_rlsat.copemerge).
# 241120-15:09:47,54 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 2 jobs ready. Free memory (GB): 451.55/453.15, Free processors: 14/22.
#                      Currently running:
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
#                        * feat_level3_rlsat.varcopemerge
#                        * feat_level3_rlsat.copemerge
# 241120-15:09:47,59 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 29.958569s.
# 241120-15:09:47,91 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/flameo".
# 241120-15:09:47,92 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame12/flameo".
# 241120-15:09:47,97 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:47,98 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:47,110 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 30.013096s.
# 241120-15:09:47,575 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 30.474102s.
# 241120-15:09:47,604 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 30.505052s.
# 241120-15:09:47,880 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 30.782601s.
# 241120-15:09:48,527 nipype.workflow INFO:
# 	 [Node] Finished "copemerge", elapsed time 31.426391s.
# 241120-15:09:48,703 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 31.606335s.
# 241120-15:09:49,52 nipype.workflow INFO:
# 	 [Job 14] Completed (feat_level3_rlsat.copemerge).
# 241120-15:09:49,54 nipype.workflow INFO:
# 	 [Job 15] Completed (feat_level3_rlsat.varcopemerge).
# 241120-15:09:49,55 nipype.workflow INFO:
# 	 [Job 16] Completed (feat_level3_rlsat.copemerge).
# 241120-15:09:49,55 nipype.workflow INFO:
# 	 [Job 17] Completed (feat_level3_rlsat.varcopemerge).
# 241120-15:09:49,56 nipype.workflow INFO:
# 	 [Job 20] Completed (feat_level3_rlsat.copemerge).
# 241120-15:09:49,57 nipype.workflow INFO:
# 	 [Job 22] Completed (feat_level3_rlsat.copemerge).
# 241120-15:09:49,57 nipype.workflow INFO:
# 	 [Job 23] Completed (feat_level3_rlsat.varcopemerge).
# 241120-15:09:49,58 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 8 jobs ready. Free memory (GB): 452.55/453.15, Free processors: 19/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.varcopemerge
# 241120-15:09:49,97 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/flameo".
# 241120-15:09:49,99 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/flameo".
# 241120-15:09:49,98 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame12/flameo".
# 241120-15:09:49,98 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/flameo".
# 241120-15:09:49,99 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame12/flameo".
# 241120-15:09:49,101 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame12/flameo".
# 241120-15:09:49,101 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/flameo".
# 241120-15:09:49,101 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame12/flameo".
# 241120-15:09:49,103 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,104 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,104 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,104 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,104 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,107 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,107 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,107 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:49,612 nipype.workflow INFO:
# 	 [Node] Finished "varcopemerge", elapsed time 32.512779s.
# 241120-15:09:51,54 nipype.workflow INFO:
# 	 [Job 25] Completed (feat_level3_rlsat.varcopemerge).
# 241120-15:09:51,56 nipype.workflow INFO:
# 	 [MultiProc] Running 10 tasks, and 2 jobs ready. Free memory (GB): 451.15/453.15, Free processors: 12/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:09:51,89 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/flameo".
# 241120-15:09:51,90 nipype.workflow INFO:
# 	 [Node] Setting-up "feat_level3_rlsat.flameo" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_5_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame12/flameo".
# 241120-15:09:51,95 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:51,96 nipype.workflow INFO:
# 	 [Node] Executing "flameo" <nipype.interfaces.fsl.model.FLAMEO>
# 241120-15:09:53,57 nipype.workflow INFO:
# 	 [MultiProc] Running 12 tasks, and 0 jobs ready. Free memory (GB): 450.75/453.15, Free processors: 10/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:44,191 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 415.086835s.
# 241120-15:16:45,457 nipype.workflow INFO:
# 	 [Job 34] Completed (feat_level3_rlsat.flameo).
# 241120-15:16:45,459 nipype.workflow INFO:
# 	 [MultiProc] Running 11 tasks, and 1 jobs ready. Free memory (GB): 450.95/453.15, Free processors: 11/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:46,620 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 417.511216s.
# 241120-15:16:46,954 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 417.84785s.
# 241120-15:16:47,459 nipype.workflow INFO:
# 	 [Job 38] Completed (feat_level3_rlsat.flameo).
# 241120-15:16:47,460 nipype.workflow INFO:
# 	 [Job 40] Completed (feat_level3_rlsat.flameo).
# 241120-15:16:47,461 nipype.workflow INFO:
# 	 [MultiProc] Running 9 tasks, and 4 jobs ready. Free memory (GB): 451.35/453.15, Free processors: 13/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:47,504 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:47,505 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:47,509 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:47,509 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:47,981 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.470204s.
# 241120-15:16:47,983 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.473066s.
# 241120-15:16:48,449 nipype.workflow INFO:
# 	 [Node] Finished "flameo", elapsed time 421.350967s.
# 241120-15:16:49,462 nipype.workflow INFO:
# 	 [Job 36] Completed (feat_level3_rlsat.flameo).
# 241120-15:16:49,463 nipype.workflow INFO:
# 	 [Job 104] Completed (_smoothestimate0).
# 241120-15:16:49,464 nipype.workflow INFO:
# 	 [Job 105] Completed (_smoothestimate1).
# 241120-15:16:49,464 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 6 jobs ready. Free memory (GB): 451.55/453.15, Free processors: 14/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:49,505 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:49,506 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 241120-15:16:49,507 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 241120-15:16:49,508 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:49,509 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 241120-15:16:49,510 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 241120-15:16:49,510 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:49,511 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:49,512 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:49,512 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:49,515 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:49,514 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:49,515 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:49,516 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:49,980 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.462769s.
# 241120-15:16:49,984 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.467431s.
# 241120-15:16:49,993 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.476296s.
# 241120-15:16:49,994 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.476381s.
# 241120-15:16:51,462 nipype.workflow INFO:
# 	 [Job 46] Completed (feat_level3_rlsat.smoothestimate).
# 241120-15:16:51,463 nipype.workflow INFO:
# 	 [Job 106] Completed (_smoothestimate0).
# 241120-15:16:51,464 nipype.workflow INFO:
# 	 [Job 107] Completed (_smoothestimate1).
# 241120-15:16:51,464 nipype.workflow INFO:
# 	 [Job 108] Completed (_smoothestimate0).
# 241120-15:16:51,465 nipype.workflow INFO:
# 	 [Job 109] Completed (_smoothestimate1).
# 241120-15:16:51,465 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 6 jobs ready. Free memory (GB): 451.55/453.15, Free processors: 14/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:51,508 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:51,510 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 241120-15:16:51,509 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:51,510 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 241120-15:16:51,511 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 241120-15:16:51,511 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:51,512 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 241120-15:16:51,512 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 241120-15:16:51,513 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:51,513 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 241120-15:16:51,514 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 241120-15:16:51,514 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 241120-15:16:51,525 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:51,526 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:51,529 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate0" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:51,529 nipype.workflow INFO:
# 	 [Node] Executing "_smoothestimate1" <nipype.interfaces.fsl.model.SmoothEstimate>
# 241120-15:16:51,992 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate1", elapsed time 0.461749s.
# 241120-15:16:52,12 nipype.workflow INFO:
# 	 [Node] Finished "_smoothestimate0", elapsed time 0.481327s.
# 241120-15:16:53,464 nipype.workflow INFO:
# 	 [Job 50] Completed (feat_level3_rlsat.smoothestimate).
# 241120-15:16:53,465 nipype.workflow INFO:
# 	 [Job 52] Completed (feat_level3_rlsat.smoothestimate).
# 241120-15:16:53,466 nipype.workflow INFO:
# 	 [Job 110] Completed (_smoothestimate0).
# 241120-15:16:53,467 nipype.workflow INFO:
# 	 [Job 111] Completed (_smoothestimate1).
# 241120-15:16:53,467 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 9 jobs ready. Free memory (GB): 451.55/453.15, Free processors: 14/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:53,505 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate0".
# 241120-15:16:53,506 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate0" - collecting precomputed outputs
# 241120-15:16:53,507 nipype.workflow INFO:
# 	 [Node] "_smoothestimate0" found cached.
# 241120-15:16:53,508 nipype.workflow INFO:
# 	 [Node] Setting-up "_smoothestimate1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_2_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/smoothestimate/mapflow/_smoothestimate1".
# 241120-15:16:53,509 nipype.workflow INFO:
# 	 [Node] Cached "_smoothestimate1" - collecting precomputed outputs
# 241120-15:16:53,510 nipype.workflow INFO:
# 	 [Node] "_smoothestimate1" found cached.
# 241120-15:16:53,528 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:53,529 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:53,530 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:53,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:53,532 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:53,533 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:53,534 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:53,535 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:54,639 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.105322s.
# 241120-15:16:54,724 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.188151s.
# 241120-15:16:54,805 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 1.270759s.
# 241120-15:16:54,832 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 1.297074s.
# 241120-15:16:55,466 nipype.workflow INFO:
# 	 [Job 48] Completed (feat_level3_rlsat.smoothestimate).
# 241120-15:16:55,467 nipype.workflow INFO:
# 	 [Job 112] Completed (_grf_cluster0).
# 241120-15:16:55,468 nipype.workflow INFO:
# 	 [Job 113] Completed (_grf_cluster1).
# 241120-15:16:55,468 nipype.workflow INFO:
# 	 [Job 114] Completed (_grf_cluster0).
# 241120-15:16:55,469 nipype.workflow INFO:
# 	 [Job 115] Completed (_grf_cluster1).
# 241120-15:16:55,470 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 12 jobs ready. Free memory (GB): 451.55/453.15, Free processors: 14/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:55,514 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:55,516 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:55,516 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 241120-15:16:55,517 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 241120-15:16:55,518 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster0" - collecting precomputed outputs
# 241120-15:16:55,518 nipype.workflow INFO:
# 	 [Node] "_grf_cluster0" found cached.
# 241120-15:16:55,518 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:55,519 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_1_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:55,520 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 241120-15:16:55,521 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 241120-15:16:55,521 nipype.workflow INFO:
# 	 [Node] Cached "_grf_cluster1" - collecting precomputed outputs
# 241120-15:16:55,521 nipype.workflow INFO:
# 	 [Node] "_grf_cluster1" found cached.
# 241120-15:16:55,528 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:55,531 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster1" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_4_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster1".
# 241120-15:16:55,532 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,534 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,535 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,536 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,536 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster0" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,536 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,536 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:55,538 nipype.workflow INFO:
# 	 [Node] Executing "_grf_cluster1" <nipype.interfaces.fsl.model.Cluster>
# 241120-15:16:56,453 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.91545s.
# 241120-15:16:56,456 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 0.911188s.
# 241120-15:16:56,591 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.051641s.
# 241120-15:16:56,649 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.111329s.
# 241120-15:16:56,725 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.187768s.
# 241120-15:16:56,764 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 1.228435s.
# 241120-15:16:56,891 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster0", elapsed time 1.353592s.
# 241120-15:16:56,897 nipype.workflow INFO:
# 	 [Node] Finished "_grf_cluster1", elapsed time 1.358597s.
# 241120-15:16:57,468 nipype.workflow INFO:
# 	 [Job 60] Completed (feat_level3_rlsat.grf_cluster).
# 241120-15:16:57,469 nipype.workflow INFO:
# 	 [Job 61] Completed (feat_level3_rlsat.grf_cluster).
# 241120-15:16:57,470 nipype.workflow INFO:
# 	 [Job 116] Completed (_grf_cluster0).
# 241120-15:16:57,470 nipype.workflow INFO:
# 	 [Job 117] Completed (_grf_cluster1).
# 241120-15:16:57,471 nipype.workflow INFO:
# 	 [Job 118] Completed (_grf_cluster0).
# 241120-15:16:57,471 nipype.workflow INFO:
# 	 [Job 119] Completed (_grf_cluster1).
# 241120-15:16:57,472 nipype.workflow INFO:
# 	 [Job 120] Completed (_grf_cluster0).
# 241120-15:16:57,472 nipype.workflow INFO:
# 	 [Job 121] Completed (_grf_cluster1).
# 241120-15:16:57,473 nipype.workflow INFO:
# 	 [Job 122] Completed (_grf_cluster0).
# 241120-15:16:57,473 nipype.workflow INFO:
# 	 [Job 123] Completed (_grf_cluster1).
# 241120-15:16:57,474 nipype.workflow INFO:
# 	 [MultiProc] Running 8 tasks, and 10 jobs ready. Free memory (GB): 451.55/453.15, Free processors: 14/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
# 241120-15:16:57,516 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_2.3/grf_cluster/mapflow/_grf_cluster0".
# 241120-15:16:57,517 nipype.workflow INFO:
# 	 [Node] Setting-up "_grf_cluster0" in "/home/Public/trondheim/processing/nipype_workflow_folders/feat_level3_rlsat/_contrast_n_3_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/_threshold_3.1/grf_cluster/mapflow/_grf_cluster0".
# ...
# 241120-15:18:27,673 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope1.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-1_flame-1_desc-cope.nii.gz
# 241120-15:18:27,673 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope1.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-1_flame-1_desc-cope.nii.gz
# 241120-15:18:27,674 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope2.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-2_flame-1_desc-cope.nii.gz
# 241120-15:18:27,674 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope2.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-2_flame-1_desc-cope.nii.gz
# 241120-15:18:27,674 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope3.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-3_flame-1_desc-cope.nii.gz
# 241120-15:18:27,675 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope3.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-3_flame-1_desc-cope.nii.gz
# 241120-15:18:27,675 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope4.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-4_flame-1_desc-cope.nii.gz
# 241120-15:18:27,675 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope4.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-4_flame-1_desc-cope.nii.gz
# 241120-15:18:27,676 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope5.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-5_flame-1_desc-cope.nii.gz
# 241120-15:18:27,676 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope5.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-5_flame-1_desc-cope.nii.gz
# 241120-15:18:27,676 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope6.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-6_flame-1_desc-cope.nii.gz
# 241120-15:18:27,676 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_copes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/cope6.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-6_flame-1_desc-cope.nii.gz
# 241120-15:18:27,677 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope1.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-1_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,677 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope1.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-1_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,678 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope2.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-2_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,678 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope2.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-2_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,678 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope3.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-3_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,679 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope3.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-3_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,679 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope4.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-4_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,680 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope4.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-4_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,680 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope5.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-5_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,680 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope5.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-5_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,680 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope6.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-6_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,681 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_varcopes/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/varcope6.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-6_flame-1_desc-varcope.nii.gz
# 241120-15:18:27,681 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t1.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-1_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,681 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t1.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-1_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,682 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t2.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-2_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,682 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t2.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-2_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,682 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t3.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-3_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,683 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t3.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-3_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,683 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t4.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-4_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,683 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t4.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-4_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,684 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t5.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-5_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,684 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t5.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-5_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,684 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t6.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-6_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,685 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/third_level_model/level3_tdof_ts/_contrast_n_0_fwhm_1p5_model_n_1-dm-RTdur/_run_mode_flame1/tdof_t6.nii.gz -> /home/Public/trondheim/derivatives/glm_feat/group_level_model/ses-rlsat/model-1-dm-RTdur/model-1-dm-RTdur_fwhm-1p5_subjectlevelcontrast-0_grouplevelcontrast-6_flame-1_desc-tdof_t.nii.gz
# 241120-15:18:27,685 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.079759s.
# 241120-15:18:27,685 nipype.workflow INFO:
# 	 [Node] Finished "sinker", elapsed time 0.078801s.
# 241120-15:18:29,562 nipype.workflow INFO:
# 	 [Job 80] Completed (feat_level3_rlsat.sinker).
# 241120-15:18:29,563 nipype.workflow INFO:
# 	 [Job 81] Completed (feat_level3_rlsat.sinker).
# 241120-15:18:29,564 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 0 jobs ready. Free memory (GB): 451.95/453.15, Free processors: 16/22.
#                      Currently running:
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo
#                        * feat_level3_rlsat.flameo

# %%
# !jupyter nbconvert --to script ./07c_GLM-FEAT-learning-tasks-group.ipynb
# Out:
# [NbConvertApp] Converting notebook ./07c_GLM-FEAT-learning-tasks-group.ipynb to script
# [NbConvertApp] Writing 14707 bytes to 07c_GLM-FEAT-learning-tasks-group.py

# %%
# # subject_ids = ['%02d' % i for i in np.arange(1, 20)]

# templates = {'level2_cope':'/home/gdholla1/projects/bias/data/derivatives/glm_fits_level2/level2_copes/_mask_{mask}_subject_id_{subject_id}/_fwhm_{fwhm}/_shift_{shift}/_flameo{contrast}/cope1.nii.gz',
#              'level2_varcope':'/home/gdholla1/projects/bias/data/derivatives/glm_fits_level2/level2_varcopes/_mask_{mask}_subject_id_{subject_id}/_fwhm_{fwhm}/_shift_{shift}/_flameo{contrast}/varcope1.nii.gz',
#              'level2_tdof':'/home/gdholla1/projects/bias/data/derivatives/glm_fits_level2/level2_tdof/_mask_{mask}_subject_id_{subject_id}/_fwhm_{fwhm}/_shift_{shift}/_flameo{contrast}/tdof_t1.nii.gz',             
#              'epi2struct':'/home/gdholla1/projects/bias/data/derivatives/registration/epi2t1weighted/epi2structmat_ants/_subject_id_{subject_id}/transformComposite.h5',
#              't1weighted':'/home/gdholla1/projects/bias/data/raw/sub-{subject_id}/anat/sub-{subject_id}_T1w.nii.gz',
#              'struct2mni':'/home/gdholla1/projects/bias/data/derivatives/registration/epi2t1weighted/struct2mnimat_ants/_subject_id_{subject_id}/transformComposite.h5',
#              'mask':fsl.Info.standard_image('MNI152_T1_1mm_brain_mask.nii.gz')}

# %%
# # Copes at level 2:
# #

# # In case you have only one cope at level 2, specify it on the input anyway.
# #Cope number from level 1
# lvl1_cope=int(sys.argv[1])
# #Cope number from level 2
# lvl2_cope=int(sys.argv[2])


# # The directory where we can find the level 2 output
# l12_out_dir=os.path.join(project_dir,"level2s","model"+model_id)

# wf = pe.Workflow(name='wf')
# wf.base_dir = os.path.join(work_dir,"wdir"+str(model_id)+"lvl3","copes_"+str(lvl1_cope)+"_"+str(lvl2_cope))
# wf.config = {"execution": {"crashdump_dir":os.path.join(project_dir,'crashdumps')}}
