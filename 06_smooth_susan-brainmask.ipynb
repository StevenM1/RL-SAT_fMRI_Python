# %% [markdown]
# ## FSL FEAT in nipype

# %%
import os
import nipype
import nipype.interfaces.io as nio
import nipype.interfaces.fsl as fsl
import nipype.interfaces.ants as ants
import nipype.pipeline.engine as pe
import nipype.interfaces.utility as util
import nipype.algorithms.modelgen as model

import glob
# Out:
# 240913-13:58:14,195 nipype.utils WARNING:
# 	 A newer version (1.8.4) of nipy/nipype is available. You are using 1.7.1

# %% [markdown]
# ## Set-up preprocessing
#
# basically we only need SUSAN smoothing

# %%
# general set-up
project_folder = '/home/Public/trondheim'
work_dir = os.path.join(project_folder, 'processing', 'nipype_workflow_folders')

smoothing_fwhm = 1.5#4.5 # 4.5 # or 1.5
t_r = 1.38
hpcutoff = 128.   # seconds

# task-specific part
subject_ids = [str(x).zfill(3) for x in range(2, 47)]
sessions = ['grids']
tasks = ['grids']
# sessions = ['rlsat']
# tasks = ['rlsat']
spaces = ['T1w'] #, 'MNI152NLin2009cAsym']

smoothing_str = str(smoothing_fwhm).replace('.', 'p')
## check for subject ids to run
# subject_ids = [x for x in subject_ids if not os.path.exists(f'../derivatives/susan_smoothed_func/sub-{x}/ses-rbrevl/func/sub-{x}_ses-rbrevl_task-rb_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-{smoothing_str}.nii.gz')]

# subs_ = [s.split('-')[1] for s in [x.split('/')[4] for x in sorted(glob.glob('../derivatives/fmriprep/fmriprep/sub-*/ses-sstmsit'))]]
#subs_ = [s.split('-')[1] for s in [x.split('/')[4] for x in sorted(glob.glob('../derivatives/fmriprep/fmriprep/sub-*/ses-rlsat'))]]
subs_ = [s.split('-')[1] for s in [x.split('/')[4] for x in sorted(glob.glob('../derivatives/fmriprep/fmriprep/sub-*/ses-grids'))]]
# already_run = [s.split('-')[1] for s in [x.split('/')[3]for x in sorted(glob.glob('../derivatives/susan_smoothed_hp_func/sub-*/ses-sstmsit/func/*task*1p5*'))]]
# to_run = [x for x in subs_ if x not in already_run]
# subject_ids = subs_
subject_ids = ['060']
# subject_ids

# subject_ids = [x for x in subject_ids if not os.path.exists(f'../derivatives/susan_smoothed_func/sub-{x}/ses-sstmsit/func/sub-{x}_ses-sstmsit_task-sst_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-{smoothing_str}.nii.gz')]
#subject_ids = [x for x in subject_ids if not os.path.exists(f'../derivatives/susan_smoothed_func/sub-{x}/ses-rlsat/func/sub-{x}_ses-rlsat_task-rlsat_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-{smoothing_str}.nii.gz')]
# subject_ids = subject_ids = [x for x in subject_ids if not os.path.exists(f'../derivatives/susan_smoothed_func/sub-{x}/ses-mrlc/func/sub-{x}_ses-mrlc_task-mt_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-{smoothing_str}.nii.gz')]
subject_ids
# Out:
# ['060']

# %%
# subject_ids = [x.split('/')[3].split('-')[1] for x in sorted(glob.glob('../sourcedata/zipdata/sub-*/ses-sstmsit'))]
# subject_ids = [s for s in subject_ids if not os.path.exists(f'../derivatives/susan_smoothed_func/sub-{s}/ses-sstmsit/func/sub-{s}_ses-sstmsit_task-sst_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-{smoothing_str}.nii.gz')]
# subject_ids

# %%
# subject_ids = ['002','003','004','005','006','007','008','009','010','011', '012','013','014',
#                '015','016','017','018','019','020','023','024','025','026', '027', 
#                '028', '029','031', '032', '033', '034', '035', '037', '038', '039'
#                '041', '042', '043', '044']
# subject_ids = ['027','029','030','031','032']
# subject_ids=['044']

subject_ids.remove('053') # no grids session in /home/Public/trondheim/derivatives/fmriprep/fmriprep/sub-*/
subject_ids.remove('054') # no grids session
subject_ids.remove('058') # no grids session
subject_ids.remove('082') # no grids session
subject_ids
# Out:
# ['045',
#  '046',
#  '048',
#  '050',
#  '051',
#  '057',
#  '059',
#  '064',
#  '065',
#  '066',
#  '068',
#  '069',
#  '070',
#  '071',
#  '073',
#  '074',
#  '075',
#  '076',
#  '078',
#  '080',
#  '083',
#  '084',
#  '085',
#  '086',
#  '087',
#  '088']

# %% [markdown]
# ## Preprocess (i.e. smooth with SUSAN)

# %%
workflow = pe.Workflow(name='smooth_wf2')
workflow.base_dir = os.path.join(work_dir, 'smoothing_wf2')
workflow.config = {"execution": {"crashdump_dir":os.path.join(project_folder, 'processing', 'crashdumps')}}

# subjects & identity1
identity = pe.Node(util.IdentityInterface(fields=['subject_id', 'ses', 'task', 'space']), name='identity')
identity.iterables = [('subject_id', subject_ids),
                      ('ses', sessions),
                      ('task', tasks),
                      ('space', spaces)]

# file selector
templates = {'func': os.path.join(project_folder, 'derivatives', 'fmriprep', 'fmriprep', 
                                  'sub-{subject_id}', 'ses-{ses}', 'func', 
                                  'sub-{subject_id}_ses-{ses}_task-{task}_run-*_space-{space}_desc-preproc_bold.nii.gz'),
             'mask': os.path.join(project_folder, 'derivatives', 'fmriprep', 'fmriprep', 
                                  'sub-{subject_id}', 'ses-{ses}', 'func', 
                                  'sub-{subject_id}_ses-{ses}_task-{task}_run-*_space-{space}_desc-brain_mask.nii.gz'),
             }
selector = pe.Node(nio.SelectFiles(templates), name='selector')

#
workflow.connect(identity, 'subject_id', selector, 'subject_id')
workflow.connect(identity, 'ses', selector, 'ses')
workflow.connect(identity, 'task', selector, 'task')
workflow.connect(identity, 'space', selector, 'space')

# convert to float
prefiltered_func_data = pe.MapNode(interface=fsl.ImageMaths(out_data_type='float',
                                             op_string = '',
                                             suffix='_dtype'),
                       iterfield=['in_file'],
                       name='convert2float', mem_gb=6)   # about 6GB in T1w space

workflow.connect(selector, 'func', prefiltered_func_data, 'in_file')

# Determine the 2nd and 98th percentile intensities of each functional 



# getthresh = pe.MapNode(interface=fsl.ImageStats(op_string='-p 2 -p 98'),
#                        iterfield = ['in_file'],
#                        name='getthreshold')

# workflow.connect(prefiltered_func_data, 'out_file', getthresh, 'in_file')

# Threshold the first run of the functional data at 10% of the 98th percentile
# threshold = pe.MapNode(interface=fsl.ImageMaths(out_data_type='char',
#                                              suffix='_thresh'),
#                     iterfield = ['in_file'],
#                     name='threshold')

# # Define a function to get 10% of the intensity
# def getthreshop(thresh):
#     return '-thr %.10f -Tmin -bin'%(0.1*thresh[0][1])

# workflow.connect(prefiltered_func_data, 'out_file', threshold, 'in_file')
# workflow.connect(getthresh, ('out_stat', getthreshop), threshold, 'op_string')

# Determine the median value of the functional runs using the mask
medianval = pe.MapNode(interface=fsl.ImageStats(op_string='-k %s -p 50'),
                       iterfield = ['in_file','mask_file'],
                       name='medianval')

workflow.connect(prefiltered_func_data, 'out_file', medianval, 'in_file')
workflow.connect(selector, 'mask', medianval, 'mask_file')


# # Dilate the mask. This is the final mask for level 1.
# dilatemask = pe.MapNode(interface=fsl.ImageMaths(suffix='_dil',
#                                               op_string='-dilF'),
#                     iterfield=['in_file'],
#                      name='dilatemask')

# workflow.connect(threshold, 'out_file', dilatemask, 'in_file')


# Mask the motion corrected functional runs with the dilated mask
prefiltered_func_data_thresh = pe.MapNode(interface=fsl.ImageMaths(suffix='_mask',
                                                op_string='-mas'),
                       iterfield=['in_file','in_file2'],
                       name='apply_brain_mask')

workflow.connect(prefiltered_func_data, 'out_file', prefiltered_func_data_thresh, 'in_file')
workflow.connect(selector, 'mask', prefiltered_func_data_thresh, 'in_file2')


# Determine the mean image from each functional run
meanfunc2 = pe.MapNode(interface=fsl.ImageMaths(op_string='-Tmean',
                                                suffix='_mean'),
                       iterfield=['in_file'],
                       name='meanfunc2')

workflow.connect(prefiltered_func_data_thresh, 'out_file', meanfunc2, 'in_file')


# Merge the median values with the mean functional images into a coupled list
# #Yes, it is Node with iterfield! Not MapNode.
mergenode = pe.Node(interface=util.Merge(2, axis='hstack'),
                       iterfield=['in1','in2'],
                       name='merge')

workflow.connect(meanfunc2,'out_file', mergenode, 'in1')
workflow.connect(medianval,'out_stat', mergenode, 'in2')


# Smooth each run using SUSAN with the brightness threshold set to 75% of the median value for each run 
# and a mask constituting the mean functional
smooth = pe.MapNode(interface=fsl.SUSAN(),
                    iterfield=['in_file', 'brightness_threshold', 'usans'],
                    name='smooth', mem_gb=10)  # reserve up to 10 GB for this node (T1w space only! otherwise use 25)
smooth.inputs.fwhm = smoothing_fwhm


# get brightness thresholds for SUSAN
def getbtthresh(medianvals):
    return [0.75*val for val in medianvals]

def getusans(x):
    ## return the mean, and 0.75* the median of the func run
    return [[tuple([val[0],0.75*val[1]])] for val in x]

workflow.connect(prefiltered_func_data_thresh, 'out_file', smooth, 'in_file')
workflow.connect(medianval, ('out_stat', getbtthresh), smooth, 'brightness_threshold')
workflow.connect(mergenode, ('out', getusans), smooth, 'usans')


# Mask the smoothed data with the dilated mask
maskfunc3 = pe.MapNode(interface=fsl.ImageMaths(suffix='_mask',
                                                op_string='-mas'),
                       iterfield=['in_file', 'in_file2'],
                       name='maskfunc3', mem_gb=10)

workflow.connect(smooth, 'smoothed_file', maskfunc3, 'in_file')
workflow.connect(selector, 'mask', maskfunc3, 'in_file2')


# Scale each volume of the run so that the median value of the run is set to 10000 (FSL convention)
intnorm = pe.MapNode(interface=fsl.ImageMaths(suffix='_intnorm'),
                     iterfield=['in_file','op_string'],
                     name='intnorm', mem_gb=10)

# Define a function to get the scaling factor for intensity normalization
def getinormscale(medianvals):
    return ['-mul %.10f'%(10000./val) for val in medianvals]

workflow.connect(maskfunc3, 'out_file', intnorm, 'in_file')
workflow.connect(medianval, ('out_stat', getinormscale), intnorm, 'op_string')


# datasink
ds = pe.Node(nio.DataSink(), name='datasink')
ds.inputs.base_directory = os.path.join(project_folder, 'derivatives')
substitutions = [('_ses_%s_space_%s_subject_id_%s_task_%s' % (ses, space, sub, task), 'sub-%s/ses-%s/func/' % (sub, ses))
                   for space in spaces 
                   for ses in sessions 
                   for sub in subject_ids
                   for task in tasks]
substitutions += [('dtype_mask_smooth_mask_intnorm', 'smoothed_fwhm-' + str(smoothing_fwhm).replace('.', 'p'))]
substitutions += [('_intnorm%d'%run, '') for run in [0,1,2,3]]  # get rid of subfolder per run
substitutions += [('_highpass%d'%run, '') for run in [0,1,2,3]] 
ds.inputs.substitutions = substitutions

workflow.connect(intnorm, 'out_file', ds, 'susan_smoothed_func')  ## smoothed functional data


# Highpass filtering below - we *do* want to do this - or maybe not?
# Create tempMean
tempMean = pe.MapNode(interface=fsl.ImageMaths(op_string='-Tmean',
                                                suffix='_mean'),
                       iterfield=['in_file'],
                       name='tempMean')

workflow.connect(intnorm, 'out_file', tempMean, 'in_file')


# Perform temporal highpass filtering on the data. This is the same as filtered_func_data in FSL output.
highpass = pe.MapNode(interface=fsl.ImageMaths(op_string= '-bptf %d -1 -add'%(hpcutoff/(2*t_r)), suffix='_tempfilt'),
                      iterfield=['in_file','in_file2'],
                      name='highpass', mem_gb=20)

workflow.connect(tempMean, 'out_file', highpass, 'in_file2')
workflow.connect(intnorm, 'out_file', highpass, 'in_file')

workflow.connect(highpass, 'out_file', ds, 'susan_smoothed_hp_func')
# workflow.connect(maskfunc3, 'out_file', ds, 'masked_func_data')  # don't save, pointless

# %%
workflow.run(plugin='MultiProc', plugin_args={'n_procs': 16, 'memory_gb': 150})
# Out:
# 240913-13:58:52,809 nipype.workflow INFO:
# 	 Workflow smooth_wf2 settings: ['check', 'execution', 'logging', 'monitoring']
# 240913-13:58:52,961 nipype.workflow INFO:
# 	 Running in parallel.
# 240913-13:58:53,169 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-13:58:53,288 nipype.workflow INFO:
# 	 [Node] Setting-up "smooth_wf2.selector" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/selector".
# 240913-13:58:53,320 nipype.workflow INFO:
# 	 [Node] Executing "selector" <nipype.interfaces.io.SelectFiles>
# 240913-13:58:53,326 nipype.workflow INFO:
# 	 [Node] Finished "selector", elapsed time 0.001382s.
# 240913-13:58:55,144 nipype.workflow INFO:
# 	 [Job 0] Completed (smooth_wf2.selector).
# 240913-13:58:55,146 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-13:58:57,146 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-13:58:57,197 nipype.workflow INFO:
# 	 [Node] Setting-up "_convert2float0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/convert2float/mapflow/_convert2float0".
# 240913-13:58:57,198 nipype.workflow INFO:
# 	 [Node] Setting-up "_convert2float2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/convert2float/mapflow/_convert2float2".
# 240913-13:58:57,197 nipype.workflow INFO:
# 	 [Node] Setting-up "_convert2float1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/convert2float/mapflow/_convert2float1".
# 240913-13:58:57,203 nipype.workflow INFO:
# 	 [Node] Executing "_convert2float0" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-13:58:57,204 nipype.workflow INFO:
# 	 [Node] Executing "_convert2float2" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-13:58:57,207 nipype.workflow INFO:
# 	 [Node] Executing "_convert2float1" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-13:58:59,148 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 132.00/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _convert2float2
#                        * _convert2float1
#                        * _convert2float0
# 240913-14:00:22,136 nipype.workflow INFO:
# 	 [Node] Finished "_convert2float0", elapsed time 84.931952s.
# 240913-14:00:23,229 nipype.workflow INFO:
# 	 [Job 12] Completed (_convert2float0).
# 240913-14:00:23,232 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 138.00/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _convert2float2
#                        * _convert2float1
# 240913-14:00:30,495 nipype.workflow INFO:
# 	 [Node] Finished "_convert2float1", elapsed time 93.286386s.
# 240913-14:00:31,237 nipype.workflow INFO:
# 	 [Job 13] Completed (_convert2float1).
# 240913-14:00:31,239 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 144.00/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _convert2float2
# 240913-14:00:47,321 nipype.workflow INFO:
# 	 [Node] Finished "_convert2float2", elapsed time 110.11521s.
# 240913-14:00:49,254 nipype.workflow INFO:
# 	 [Job 14] Completed (_convert2float2).
# 240913-14:00:49,256 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:00:49,375 nipype.workflow INFO:
# 	 [Node] Setting-up "_convert2float0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/convert2float/mapflow/_convert2float0".
# 240913-14:00:49,413 nipype.workflow INFO:
# 	 [Node] Cached "_convert2float0" - collecting precomputed outputs
# 240913-14:00:49,427 nipype.workflow INFO:
# 	 [Node] "_convert2float0" found cached.
# 240913-14:00:49,448 nipype.workflow INFO:
# 	 [Node] Setting-up "_convert2float1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/convert2float/mapflow/_convert2float1".
# 240913-14:00:49,469 nipype.workflow INFO:
# 	 [Node] Cached "_convert2float1" - collecting precomputed outputs
# 240913-14:00:49,491 nipype.workflow INFO:
# 	 [Node] "_convert2float1" found cached.
# 240913-14:00:49,512 nipype.workflow INFO:
# 	 [Node] Setting-up "_convert2float2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/convert2float/mapflow/_convert2float2".
# 240913-14:00:49,534 nipype.workflow INFO:
# 	 [Node] Cached "_convert2float2" - collecting precomputed outputs
# 240913-14:00:49,555 nipype.workflow INFO:
# 	 [Node] "_convert2float2" found cached.
# 240913-14:00:51,255 nipype.workflow INFO:
# 	 [Job 1] Completed (smooth_wf2.convert2float).
# 240913-14:00:51,267 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 2 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:00:53,257 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:00:53,357 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_brain_mask0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/apply_brain_mask/mapflow/_apply_brain_mask0".
# 240913-14:00:53,360 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_brain_mask1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/apply_brain_mask/mapflow/_apply_brain_mask1".
# 240913-14:00:53,361 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_brain_mask2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/apply_brain_mask/mapflow/_apply_brain_mask2".
# 240913-14:00:53,355 nipype.workflow INFO:
# 	 [Node] Setting-up "_medianval0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/medianval/mapflow/_medianval0".
# 240913-14:00:53,356 nipype.workflow INFO:
# 	 [Node] Setting-up "_medianval1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/medianval/mapflow/_medianval1".
# 240913-14:00:53,356 nipype.workflow INFO:
# 	 [Node] Setting-up "_medianval2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/medianval/mapflow/_medianval2".
# 240913-14:00:53,383 nipype.workflow INFO:
# 	 [Node] Executing "_medianval0" <nipype.interfaces.fsl.utils.ImageStats>
# 240913-14:00:53,380 nipype.workflow INFO:
# 	 [Node] Executing "_apply_brain_mask1" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:00:53,380 nipype.workflow INFO:
# 	 [Node] Executing "_apply_brain_mask0" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:00:53,384 nipype.workflow INFO:
# 	 [Node] Executing "_medianval1" <nipype.interfaces.fsl.utils.ImageStats>
# 240913-14:00:53,383 nipype.workflow INFO:
# 	 [Node] Executing "_apply_brain_mask2" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:00:53,385 nipype.workflow INFO:
# 	 [Node] Executing "_medianval2" <nipype.interfaces.fsl.utils.ImageStats>
# 240913-14:00:55,259 nipype.workflow INFO:
# 	 [MultiProc] Running 6 tasks, and 0 jobs ready. Free memory (GB): 148.80/150.00, Free processors: 10/16.
#                      Currently running:
#                        * _apply_brain_mask2
#                        * _apply_brain_mask1
#                        * _apply_brain_mask0
#                        * _medianval2
#                        * _medianval1
#                        * _medianval0
# 240913-14:01:55,361 nipype.workflow INFO:
# 	 [Node] Finished "_medianval0", elapsed time 61.964338s.
# 240913-14:01:56,713 nipype.workflow INFO:
# 	 [Node] Finished "_apply_brain_mask0", elapsed time 63.315864s.
# 240913-14:01:57,319 nipype.workflow INFO:
# 	 [Job 15] Completed (_medianval0).
# 240913-14:01:57,353 nipype.workflow INFO:
# 	 [Job 18] Completed (_apply_brain_mask0).
# 240913-14:01:57,355 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 149.20/150.00, Free processors: 12/16.
#                      Currently running:
#                        * _apply_brain_mask2
#                        * _apply_brain_mask1
#                        * _medianval2
#                        * _medianval1
# 240913-14:02:09,693 nipype.workflow INFO:
# 	 [Node] Finished "_apply_brain_mask2", elapsed time 76.293504s.
# 240913-14:02:11,333 nipype.workflow INFO:
# 	 [Job 20] Completed (_apply_brain_mask2).
# 240913-14:02:11,335 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 149.40/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _apply_brain_mask1
#                        * _medianval2
#                        * _medianval1
# 240913-14:02:13,655 nipype.workflow INFO:
# 	 [Node] Finished "_medianval2", elapsed time 80.250194s.
# 240913-14:02:14,910 nipype.workflow INFO:
# 	 [Node] Finished "_apply_brain_mask1", elapsed time 81.513437s.
# 240913-14:02:15,337 nipype.workflow INFO:
# 	 [Job 17] Completed (_medianval2).
# 240913-14:02:15,338 nipype.workflow INFO:
# 	 [Job 19] Completed (_apply_brain_mask1).
# 240913-14:02:15,340 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 149.80/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _medianval1
# 240913-14:02:15,762 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_brain_mask0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/apply_brain_mask/mapflow/_apply_brain_mask0".
# 240913-14:02:15,769 nipype.workflow INFO:
# 	 [Node] Cached "_apply_brain_mask0" - collecting precomputed outputs
# 240913-14:02:15,772 nipype.workflow INFO:
# 	 [Node] "_apply_brain_mask0" found cached.
# 240913-14:02:15,774 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_brain_mask1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/apply_brain_mask/mapflow/_apply_brain_mask1".
# 240913-14:02:15,784 nipype.workflow INFO:
# 	 [Node] Cached "_apply_brain_mask1" - collecting precomputed outputs
# 240913-14:02:15,807 nipype.workflow INFO:
# 	 [Node] "_apply_brain_mask1" found cached.
# 240913-14:02:15,832 nipype.workflow INFO:
# 	 [Node] Setting-up "_apply_brain_mask2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/apply_brain_mask/mapflow/_apply_brain_mask2".
# 240913-14:02:15,845 nipype.workflow INFO:
# 	 [Node] Cached "_apply_brain_mask2" - collecting precomputed outputs
# 240913-14:02:15,859 nipype.workflow INFO:
# 	 [Node] "_apply_brain_mask2" found cached.
# 240913-14:02:17,339 nipype.workflow INFO:
# 	 [Job 3] Completed (smooth_wf2.apply_brain_mask).
# 240913-14:02:17,341 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 149.80/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _medianval1
# 240913-14:02:17,600 nipype.workflow INFO:
# 	 [Node] Finished "_medianval1", elapsed time 84.202456s.
# 240913-14:02:19,341 nipype.workflow INFO:
# 	 [Job 16] Completed (_medianval1).
# 240913-14:02:19,344 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:02:19,397 nipype.workflow INFO:
# 	 [Node] Setting-up "_meanfunc20" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/meanfunc2/mapflow/_meanfunc20".
# 240913-14:02:19,398 nipype.workflow INFO:
# 	 [Node] Setting-up "_meanfunc21" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/meanfunc2/mapflow/_meanfunc21".
# 240913-14:02:19,404 nipype.workflow INFO:
# 	 [Node] Executing "_meanfunc20" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:02:19,402 nipype.workflow INFO:
# 	 [Node] Setting-up "_medianval0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/medianval/mapflow/_medianval0".
# 240913-14:02:19,406 nipype.workflow INFO:
# 	 [Node] Executing "_meanfunc21" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:02:19,398 nipype.workflow INFO:
# 	 [Node] Setting-up "_meanfunc22" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/meanfunc2/mapflow/_meanfunc22".
# 240913-14:02:19,413 nipype.workflow INFO:
# 	 [Node] Cached "_medianval0" - collecting precomputed outputs
# 240913-14:02:19,416 nipype.workflow INFO:
# 	 [Node] "_medianval0" found cached.
# 240913-14:02:19,418 nipype.workflow INFO:
# 	 [Node] Setting-up "_medianval1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/medianval/mapflow/_medianval1".
# 240913-14:02:19,417 nipype.workflow INFO:
# 	 [Node] Executing "_meanfunc22" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:02:19,419 nipype.workflow INFO:
# 	 [Node] Cached "_medianval1" - collecting precomputed outputs
# 240913-14:02:19,423 nipype.workflow INFO:
# 	 [Node] "_medianval1" found cached.
# 240913-14:02:19,425 nipype.workflow INFO:
# 	 [Node] Setting-up "_medianval2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/medianval/mapflow/_medianval2".
# 240913-14:02:19,428 nipype.workflow INFO:
# 	 [Node] Cached "_medianval2" - collecting precomputed outputs
# 240913-14:02:19,429 nipype.workflow INFO:
# 	 [Node] "_medianval2" found cached.
# 240913-14:02:21,343 nipype.workflow INFO:
# 	 [Job 2] Completed (smooth_wf2.medianval).
# 240913-14:02:21,345 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 149.40/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _meanfunc22
#                        * _meanfunc21
#                        * _meanfunc20
# 240913-14:02:43,53 nipype.workflow INFO:
# 	 [Node] Finished "_meanfunc20", elapsed time 23.646135s.
# 240913-14:02:43,363 nipype.workflow INFO:
# 	 [Job 21] Completed (_meanfunc20).
# 240913-14:02:43,365 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 149.60/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _meanfunc22
#                        * _meanfunc21
# 240913-14:02:43,722 nipype.workflow INFO:
# 	 [Node] Finished "_meanfunc21", elapsed time 24.312705s.
# 240913-14:02:45,365 nipype.workflow INFO:
# 	 [Job 22] Completed (_meanfunc21).
# 240913-14:02:45,366 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 149.80/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _meanfunc22
# 240913-14:02:48,75 nipype.workflow INFO:
# 	 [Node] Finished "_meanfunc22", elapsed time 28.654112s.
# 240913-14:02:49,369 nipype.workflow INFO:
# 	 [Job 23] Completed (_meanfunc22).
# 240913-14:02:49,370 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:02:49,441 nipype.workflow INFO:
# 	 [Node] Setting-up "_meanfunc20" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/meanfunc2/mapflow/_meanfunc20".
# 240913-14:02:49,443 nipype.workflow INFO:
# 	 [Node] Cached "_meanfunc20" - collecting precomputed outputs
# 240913-14:02:49,447 nipype.workflow INFO:
# 	 [Node] "_meanfunc20" found cached.
# 240913-14:02:49,449 nipype.workflow INFO:
# 	 [Node] Setting-up "_meanfunc21" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/meanfunc2/mapflow/_meanfunc21".
# 240913-14:02:49,452 nipype.workflow INFO:
# 	 [Node] Cached "_meanfunc21" - collecting precomputed outputs
# 240913-14:02:49,467 nipype.workflow INFO:
# 	 [Node] "_meanfunc21" found cached.
# 240913-14:02:49,472 nipype.workflow INFO:
# 	 [Node] Setting-up "_meanfunc22" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/meanfunc2/mapflow/_meanfunc22".
# 240913-14:02:49,477 nipype.workflow INFO:
# 	 [Node] Cached "_meanfunc22" - collecting precomputed outputs
# 240913-14:02:49,499 nipype.workflow INFO:
# 	 [Node] "_meanfunc22" found cached.
# 240913-14:02:51,371 nipype.workflow INFO:
# 	 [Job 4] Completed (smooth_wf2.meanfunc2).
# 240913-14:02:51,373 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:02:51,420 nipype.workflow INFO:
# 	 [Node] Setting-up "smooth_wf2.merge" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/merge".
# 240913-14:02:51,426 nipype.workflow INFO:
# 	 [Node] Executing "merge" <nipype.interfaces.utility.base.Merge>
# 240913-14:02:51,428 nipype.workflow INFO:
# 	 [Node] Finished "merge", elapsed time 0.000194s.
# 240913-14:02:53,373 nipype.workflow INFO:
# 	 [Job 5] Completed (smooth_wf2.merge).
# 240913-14:02:53,375 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:02:55,376 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:02:55,474 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/smooth/mapflow/_smooth1".
# 240913-14:02:55,473 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/smooth/mapflow/_smooth0".
# 240913-14:02:55,479 nipype.workflow INFO:
# 	 [Node] Executing "_smooth1" <nipype.interfaces.fsl.preprocess.SUSAN>
# 240913-14:02:55,474 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/smooth/mapflow/_smooth2".
# 240913-14:02:55,493 nipype.workflow INFO:
# 	 [Node] Executing "_smooth2" <nipype.interfaces.fsl.preprocess.SUSAN>
# 240913-14:02:55,490 nipype.workflow INFO:
# 	 [Node] Executing "_smooth0" <nipype.interfaces.fsl.preprocess.SUSAN>
# 240913-14:02:57,378 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 120.00/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _smooth2
#                        * _smooth1
#                        * _smooth0
# 240913-14:11:04,902 nipype.workflow INFO:
# 	 [Node] Finished "_smooth0", elapsed time 489.398882s.
# 240913-14:11:05,873 nipype.workflow INFO:
# 	 [Job 24] Completed (_smooth0).
# 240913-14:11:05,913 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 130.00/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _smooth2
#                        * _smooth1
# 240913-14:12:34,590 nipype.workflow INFO:
# 	 [Node] Finished "_smooth1", elapsed time 579.108941s.
# 240913-14:12:35,988 nipype.workflow INFO:
# 	 [Job 25] Completed (_smooth1).
# 240913-14:12:35,990 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 140.00/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _smooth2
# 240913-14:13:04,92 nipype.workflow INFO:
# 	 [Node] Finished "_smooth2", elapsed time 608.597019s.
# 240913-14:13:06,14 nipype.workflow INFO:
# 	 [Job 26] Completed (_smooth2).
# 240913-14:13:06,17 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:13:06,128 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/smooth/mapflow/_smooth0".
# 240913-14:13:06,144 nipype.workflow INFO:
# 	 [Node] Cached "_smooth0" - collecting precomputed outputs
# 240913-14:13:06,159 nipype.workflow INFO:
# 	 [Node] "_smooth0" found cached.
# 240913-14:13:06,175 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/smooth/mapflow/_smooth1".
# 240913-14:13:06,184 nipype.workflow INFO:
# 	 [Node] Cached "_smooth1" - collecting precomputed outputs
# 240913-14:13:06,199 nipype.workflow INFO:
# 	 [Node] "_smooth1" found cached.
# 240913-14:13:06,208 nipype.workflow INFO:
# 	 [Node] Setting-up "_smooth2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/smooth/mapflow/_smooth2".
# 240913-14:13:06,215 nipype.workflow INFO:
# 	 [Node] Cached "_smooth2" - collecting precomputed outputs
# 240913-14:13:06,229 nipype.workflow INFO:
# 	 [Node] "_smooth2" found cached.
# 240913-14:13:08,15 nipype.workflow INFO:
# 	 [Job 6] Completed (smooth_wf2.smooth).
# 240913-14:13:08,17 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:13:10,18 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:13:10,70 nipype.workflow INFO:
# 	 [Node] Setting-up "_maskfunc30" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/maskfunc3/mapflow/_maskfunc30".
# 240913-14:13:10,70 nipype.workflow INFO:
# 	 [Node] Setting-up "_maskfunc31" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/maskfunc3/mapflow/_maskfunc31".
# 240913-14:13:10,71 nipype.workflow INFO:
# 	 [Node] Setting-up "_maskfunc32" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/maskfunc3/mapflow/_maskfunc32".
# 240913-14:13:10,76 nipype.workflow INFO:
# 	 [Node] Executing "_maskfunc30" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:13:10,77 nipype.workflow INFO:
# 	 [Node] Executing "_maskfunc31" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:13:10,80 nipype.workflow INFO:
# 	 [Node] Executing "_maskfunc32" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:13:12,20 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 120.00/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _maskfunc32
#                        * _maskfunc31
#                        * _maskfunc30
# 240913-14:13:49,786 nipype.workflow INFO:
# 	 [Node] Finished "_maskfunc30", elapsed time 39.708403s.
# 240913-14:13:50,57 nipype.workflow INFO:
# 	 [Job 27] Completed (_maskfunc30).
# 240913-14:13:50,60 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 130.00/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _maskfunc32
#                        * _maskfunc31
# 240913-14:14:06,442 nipype.workflow INFO:
# 	 [Node] Finished "_maskfunc32", elapsed time 56.358459s.
# 240913-14:14:07,510 nipype.workflow INFO:
# 	 [Node] Finished "_maskfunc31", elapsed time 57.428242s.
# 240913-14:14:08,75 nipype.workflow INFO:
# 	 [Job 28] Completed (_maskfunc31).
# 240913-14:14:08,77 nipype.workflow INFO:
# 	 [Job 29] Completed (_maskfunc32).
# 240913-14:14:08,78 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:14:08,134 nipype.workflow INFO:
# 	 [Node] Setting-up "_maskfunc30" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/maskfunc3/mapflow/_maskfunc30".
# 240913-14:14:08,138 nipype.workflow INFO:
# 	 [Node] Cached "_maskfunc30" - collecting precomputed outputs
# 240913-14:14:08,140 nipype.workflow INFO:
# 	 [Node] "_maskfunc30" found cached.
# 240913-14:14:08,143 nipype.workflow INFO:
# 	 [Node] Setting-up "_maskfunc31" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/maskfunc3/mapflow/_maskfunc31".
# 240913-14:14:08,146 nipype.workflow INFO:
# 	 [Node] Cached "_maskfunc31" - collecting precomputed outputs
# 240913-14:14:08,148 nipype.workflow INFO:
# 	 [Node] "_maskfunc31" found cached.
# 240913-14:14:08,151 nipype.workflow INFO:
# 	 [Node] Setting-up "_maskfunc32" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/maskfunc3/mapflow/_maskfunc32".
# 240913-14:14:08,154 nipype.workflow INFO:
# 	 [Node] Cached "_maskfunc32" - collecting precomputed outputs
# 240913-14:14:08,156 nipype.workflow INFO:
# 	 [Node] "_maskfunc32" found cached.
# 240913-14:14:10,79 nipype.workflow INFO:
# 	 [Job 7] Completed (smooth_wf2.maskfunc3).
# 240913-14:14:10,82 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:14:12,81 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:14:12,133 nipype.workflow INFO:
# 	 [Node] Setting-up "_intnorm0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/intnorm/mapflow/_intnorm0".
# 240913-14:14:12,136 nipype.workflow INFO:
# 	 [Node] Setting-up "_intnorm2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/intnorm/mapflow/_intnorm2".
# 240913-14:14:12,134 nipype.workflow INFO:
# 	 [Node] Setting-up "_intnorm1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/intnorm/mapflow/_intnorm1".
# 240913-14:14:12,139 nipype.workflow INFO:
# 	 [Node] Executing "_intnorm0" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:14:12,141 nipype.workflow INFO:
# 	 [Node] Executing "_intnorm2" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:14:12,142 nipype.workflow INFO:
# 	 [Node] Executing "_intnorm1" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:14:14,83 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 120.00/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _intnorm2
#                        * _intnorm1
#                        * _intnorm0
# 240913-14:14:52,846 nipype.workflow INFO:
# 	 [Node] Finished "_intnorm0", elapsed time 40.688897s.
# 240913-14:14:54,121 nipype.workflow INFO:
# 	 [Job 30] Completed (_intnorm0).
# 240913-14:14:54,123 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 130.00/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _intnorm2
#                        * _intnorm1
# 240913-14:15:04,697 nipype.workflow INFO:
# 	 [Node] Finished "_intnorm1", elapsed time 52.553034s.
# 240913-14:15:06,133 nipype.workflow INFO:
# 	 [Job 31] Completed (_intnorm1).
# 240913-14:15:06,135 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 140.00/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _intnorm2
# 240913-14:15:09,878 nipype.workflow INFO:
# 	 [Node] Finished "_intnorm2", elapsed time 57.735086s.
# 240913-14:15:10,138 nipype.workflow INFO:
# 	 [Job 32] Completed (_intnorm2).
# 240913-14:15:10,139 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:15:10,190 nipype.workflow INFO:
# 	 [Node] Setting-up "_intnorm0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/intnorm/mapflow/_intnorm0".
# 240913-14:15:10,193 nipype.workflow INFO:
# 	 [Node] Cached "_intnorm0" - collecting precomputed outputs
# 240913-14:15:10,196 nipype.workflow INFO:
# 	 [Node] "_intnorm0" found cached.
# 240913-14:15:10,198 nipype.workflow INFO:
# 	 [Node] Setting-up "_intnorm1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/intnorm/mapflow/_intnorm1".
# 240913-14:15:10,200 nipype.workflow INFO:
# 	 [Node] Cached "_intnorm1" - collecting precomputed outputs
# 240913-14:15:10,202 nipype.workflow INFO:
# 	 [Node] "_intnorm1" found cached.
# 240913-14:15:10,203 nipype.workflow INFO:
# 	 [Node] Setting-up "_intnorm2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/intnorm/mapflow/_intnorm2".
# 240913-14:15:10,205 nipype.workflow INFO:
# 	 [Node] Cached "_intnorm2" - collecting precomputed outputs
# 240913-14:15:10,205 nipype.workflow INFO:
# 	 [Node] "_intnorm2" found cached.
# 240913-14:15:12,140 nipype.workflow INFO:
# 	 [Job 8] Completed (smooth_wf2.intnorm).
# 240913-14:15:12,141 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:15:14,142 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:15:14,188 nipype.workflow INFO:
# 	 [Node] Setting-up "_tempMean0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/tempMean/mapflow/_tempMean0".
# 240913-14:15:14,190 nipype.workflow INFO:
# 	 [Node] Setting-up "_tempMean1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/tempMean/mapflow/_tempMean1".
# 240913-14:15:14,190 nipype.workflow INFO:
# 	 [Node] Setting-up "_tempMean2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/tempMean/mapflow/_tempMean2".
# 240913-14:15:14,194 nipype.workflow INFO:
# 	 [Node] Executing "_tempMean0" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:15:14,195 nipype.workflow INFO:
# 	 [Node] Executing "_tempMean1" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:15:14,196 nipype.workflow INFO:
# 	 [Node] Executing "_tempMean2" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:15:16,144 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 149.40/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _tempMean2
#                        * _tempMean1
#                        * _tempMean0
# 240913-14:15:31,911 nipype.workflow INFO:
# 	 [Node] Finished "_tempMean0", elapsed time 17.715066s.
# 240913-14:15:32,159 nipype.workflow INFO:
# 	 [Job 33] Completed (_tempMean0).
# 240913-14:15:32,161 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 149.60/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _tempMean2
#                        * _tempMean1
# 240913-14:15:41,223 nipype.workflow INFO:
# 	 [Node] Finished "_tempMean1", elapsed time 27.025498s.
# 240913-14:15:41,820 nipype.workflow INFO:
# 	 [Node] Finished "_tempMean2", elapsed time 27.622907s.
# 240913-14:15:42,169 nipype.workflow INFO:
# 	 [Job 34] Completed (_tempMean1).
# 240913-14:15:42,170 nipype.workflow INFO:
# 	 [Job 35] Completed (_tempMean2).
# 240913-14:15:42,171 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:15:42,223 nipype.workflow INFO:
# 	 [Node] Setting-up "_tempMean0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/tempMean/mapflow/_tempMean0".
# 240913-14:15:42,225 nipype.workflow INFO:
# 	 [Node] Cached "_tempMean0" - collecting precomputed outputs
# 240913-14:15:42,227 nipype.workflow INFO:
# 	 [Node] "_tempMean0" found cached.
# 240913-14:15:42,229 nipype.workflow INFO:
# 	 [Node] Setting-up "_tempMean1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/tempMean/mapflow/_tempMean1".
# 240913-14:15:42,231 nipype.workflow INFO:
# 	 [Node] Cached "_tempMean1" - collecting precomputed outputs
# 240913-14:15:42,233 nipype.workflow INFO:
# 	 [Node] "_tempMean1" found cached.
# 240913-14:15:42,236 nipype.workflow INFO:
# 	 [Node] Setting-up "_tempMean2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/tempMean/mapflow/_tempMean2".
# 240913-14:15:42,239 nipype.workflow INFO:
# 	 [Node] Cached "_tempMean2" - collecting precomputed outputs
# 240913-14:15:42,241 nipype.workflow INFO:
# 	 [Node] "_tempMean2" found cached.
# 240913-14:15:44,171 nipype.workflow INFO:
# 	 [Job 9] Completed (smooth_wf2.tempMean).
# 240913-14:15:44,173 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:15:46,174 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:15:46,221 nipype.workflow INFO:
# 	 [Node] Setting-up "_highpass0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/highpass/mapflow/_highpass0".
# 240913-14:15:46,222 nipype.workflow INFO:
# 	 [Node] Setting-up "_highpass1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/highpass/mapflow/_highpass1".
# 240913-14:15:46,229 nipype.workflow INFO:
# 	 [Node] Executing "_highpass1" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:15:46,237 nipype.workflow INFO:
# 	 [Node] Executing "_highpass0" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:15:46,222 nipype.workflow INFO:
# 	 [Node] Setting-up "_highpass2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/highpass/mapflow/_highpass2".
# 240913-14:15:46,250 nipype.workflow INFO:
# 	 [Node] Executing "_highpass2" <nipype.interfaces.fsl.utils.ImageMaths>
# 240913-14:15:48,176 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 90.00/150.00, Free processors: 13/16.
#                      Currently running:
#                        * _highpass2
#                        * _highpass1
#                        * _highpass0
# 240913-14:23:06,733 nipype.workflow INFO:
# 	 [Node] Finished "_highpass0", elapsed time 440.492871s.
# 240913-14:23:08,609 nipype.workflow INFO:
# 	 [Job 36] Completed (_highpass0).
# 240913-14:23:08,611 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 110.00/150.00, Free processors: 14/16.
#                      Currently running:
#                        * _highpass2
#                        * _highpass1
# 240913-14:25:48,956 nipype.workflow INFO:
# 	 [Node] Finished "_highpass2", elapsed time 602.703123s.
# 240913-14:25:50,764 nipype.workflow INFO:
# 	 [Job 38] Completed (_highpass2).
# 240913-14:25:50,765 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 130.00/150.00, Free processors: 15/16.
#                      Currently running:
#                        * _highpass1
# 240913-14:25:54,990 nipype.workflow INFO:
# 	 [Node] Finished "_highpass1", elapsed time 608.756317s.
# 240913-14:25:56,769 nipype.workflow INFO:
# 	 [Job 37] Completed (_highpass1).
# 240913-14:25:56,772 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:25:56,837 nipype.workflow INFO:
# 	 [Node] Setting-up "_highpass0" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/highpass/mapflow/_highpass0".
# 240913-14:25:56,840 nipype.workflow INFO:
# 	 [Node] Cached "_highpass0" - collecting precomputed outputs
# 240913-14:25:56,844 nipype.workflow INFO:
# 	 [Node] "_highpass0" found cached.
# 240913-14:25:56,846 nipype.workflow INFO:
# 	 [Node] Setting-up "_highpass1" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/highpass/mapflow/_highpass1".
# 240913-14:25:56,850 nipype.workflow INFO:
# 	 [Node] Cached "_highpass1" - collecting precomputed outputs
# 240913-14:25:56,851 nipype.workflow INFO:
# 	 [Node] "_highpass1" found cached.
# 240913-14:25:56,854 nipype.workflow INFO:
# 	 [Node] Setting-up "_highpass2" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/highpass/mapflow/_highpass2".
# 240913-14:25:56,856 nipype.workflow INFO:
# 	 [Node] Cached "_highpass2" - collecting precomputed outputs
# 240913-14:25:56,859 nipype.workflow INFO:
# 	 [Node] "_highpass2" found cached.
# 240913-14:25:58,771 nipype.workflow INFO:
# 	 [Job 10] Completed (smooth_wf2.highpass).
# 240913-14:25:58,773 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.
# 240913-14:25:58,858 nipype.workflow INFO:
# 	 [Node] Setting-up "smooth_wf2.datasink" in "/home/Public/trondheim/processing/nipype_workflow_folders/smoothing_wf2/smooth_wf2/_ses_grids_space_T1w_subject_id_060_task_grids/datasink".
# 240913-14:25:58,866 nipype.workflow INFO:
# 	 [Node] Executing "datasink" <nipype.interfaces.io.DataSink>
# 240913-14:25:58,869 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/susan_smoothed_func/_ses_grids_space_T1w_subject_id_060_task_grids/_intnorm0/sub-060_ses-grids_task-grids_run-1_space-T1w_desc-preproc_bold_dtype_mask_smooth_mask_intnorm.nii.gz -> /home/Public/trondheim/derivatives/susan_smoothed_func/sub-060/ses-grids/func///sub-060_ses-grids_task-grids_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-1p5.nii.gz
# 240913-14:25:58,929 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/susan_smoothed_func/_ses_grids_space_T1w_subject_id_060_task_grids/_intnorm1/sub-060_ses-grids_task-grids_run-2_space-T1w_desc-preproc_bold_dtype_mask_smooth_mask_intnorm.nii.gz -> /home/Public/trondheim/derivatives/susan_smoothed_func/sub-060/ses-grids/func///sub-060_ses-grids_task-grids_run-2_space-T1w_desc-preproc_bold_smoothed_fwhm-1p5.nii.gz
# 240913-14:25:58,931 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/susan_smoothed_func/_ses_grids_space_T1w_subject_id_060_task_grids/_intnorm2/sub-060_ses-grids_task-grids_run-3_space-T1w_desc-preproc_bold_dtype_mask_smooth_mask_intnorm.nii.gz -> /home/Public/trondheim/derivatives/susan_smoothed_func/sub-060/ses-grids/func///sub-060_ses-grids_task-grids_run-3_space-T1w_desc-preproc_bold_smoothed_fwhm-1p5.nii.gz
# 240913-14:25:58,934 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/susan_smoothed_hp_func/_ses_grids_space_T1w_subject_id_060_task_grids/_highpass0/sub-060_ses-grids_task-grids_run-1_space-T1w_desc-preproc_bold_dtype_mask_smooth_mask_intnorm_tempfilt.nii.gz -> /home/Public/trondheim/derivatives/susan_smoothed_hp_func/sub-060/ses-grids/func///sub-060_ses-grids_task-grids_run-1_space-T1w_desc-preproc_bold_smoothed_fwhm-1p5_tempfilt.nii.gz
# 240913-14:25:58,939 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/susan_smoothed_hp_func/_ses_grids_space_T1w_subject_id_060_task_grids/_highpass1/sub-060_ses-grids_task-grids_run-2_space-T1w_desc-preproc_bold_dtype_mask_smooth_mask_intnorm_tempfilt.nii.gz -> /home/Public/trondheim/derivatives/susan_smoothed_hp_func/sub-060/ses-grids/func///sub-060_ses-grids_task-grids_run-2_space-T1w_desc-preproc_bold_smoothed_fwhm-1p5_tempfilt.nii.gz
# 240913-14:25:58,941 nipype.interface INFO:
# 	 sub: /home/Public/trondheim/derivatives/susan_smoothed_hp_func/_ses_grids_space_T1w_subject_id_060_task_grids/_highpass2/sub-060_ses-grids_task-grids_run-3_space-T1w_desc-preproc_bold_dtype_mask_smooth_mask_intnorm_tempfilt.nii.gz -> /home/Public/trondheim/derivatives/susan_smoothed_hp_func/sub-060/ses-grids/func///sub-060_ses-grids_task-grids_run-3_space-T1w_desc-preproc_bold_smoothed_fwhm-1p5_tempfilt.nii.gz
# 240913-14:25:58,943 nipype.workflow INFO:
# 	 [Node] Finished "datasink", elapsed time 0.073942s.
# 240913-14:26:00,773 nipype.workflow INFO:
# 	 [Job 11] Completed (smooth_wf2.datasink).
# 240913-14:26:00,775 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 150.00/150.00, Free processors: 16/16.

# %%
# from nipype.utils.filemanip import loadpkl
# res = loadpkl('/home/Public/trondheim/processing/crashdumps/crash-20220116-122933-scotti-selector.a20-9e5d7a36-8777-4dd2-b1ee-263ec58edb60.pklz')
# res
# Out:
# {'node': smooth_wf2.selector.a20,
#  'traceback': ['Traceback (most recent call last):\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/pipeline/plugins/multiproc.py", line 67, in run_node\n    result["result"] = node.run(updatehash=updatehash)\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 516, in run\n    result = self._run_interface(execute=True)\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 635, in _run_interface\n    return self._run_command(execute)\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/pipeline/engine/nodes.py", line 741, in _run_command\n    result = self._interface.run(cwd=outdir)\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 436, in run\n    outputs = self.aggregate_outputs(runtime)\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/interfaces/base/core.py", line 513, in aggregate_outputs\n    predicted_outputs = self._list_outputs()  # Predictions from _list_outputs\n',
#   '  File "/home/scotti/.conda/envs/py38/lib/python3.8/site-packages/nipype/interfaces/io.py", line 1474, in _list_outputs\n    raise IOError(msg)\n',
#   'OSError: No files were found matching func template: /home/Public/trondheim/derivatives/fmriprep/fmriprep/sub-022/ses-sstmsit/func/sub-022_ses-sstmsit_task-sst_run-*_space-T1w_desc-preproc_bold.nii.gz\n']}
